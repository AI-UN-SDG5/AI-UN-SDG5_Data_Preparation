# %% [markdown]
# # Data Preparation
# This notebook is used to generated the requisite config csv file for the AI-UN-SDG5 application and database to be functional. Refer to the README.md file on instructions on how to execute this notebook.

# %%
# Install necessary packages
# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: countryinfo in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: hdx-python-country in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (3.8.3)
# Requirement already satisfied: jupyter in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: pandas in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: phone-iso3166 in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: phonenumbers in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (8.13.49)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: uuid in ./.venv/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (1.30)
# Requirement already satisfied: tenacity in ./.venv/lib/python3.10/site-packages (from hdx-python-country->-r requirements.txt (line 2)) (9.0.0)
# Requirement already satisfied: pyphonetics in ./.venv/lib/python3.10/site-packages (from hdx-python-country->-r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: libhxl>=5.2.2 in ./.venv/lib/python3.10/site-packages (from hdx-python-country->-r requirements.txt (line 2)) (5.2.2)
# Requirement already satisfied: hdx-python-utilities>=3.7.4 in ./.venv/lib/python3.10/site-packages (from hdx-python-country->-r requirements.txt (line 2)) (3.7.4)
# Requirement already satisfied: nbconvert in ./.venv/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 3)) (7.16.4)
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 3)) (6.29.5)
# Requirement already satisfied: ipywidgets in ./.venv/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 3)) (8.1.5)
# Requirement already satisfied: notebook in ./.venv/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 3)) (7.2.2)
# Requirement already satisfied: jupyter-console in ./.venv/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 3)) (6.6.3)
# Requirement already satisfied: jupyterlab in ./.venv/lib/python3.10/site-packages (from jupyter->-r requirements.txt (line 3)) (4.2.5)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: ratelimit in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: frictionless>=5.18.0 in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (5.18.0)
# Requirement already satisfied: requests-file in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: xlsx2csv in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.8.3)
# Requirement already satisfied: ruamel-yaml in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.18.6)
# Requirement already satisfied: openpyxl>=3.1.2 in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (3.1.5)
# Requirement already satisfied: jsonlines>=4.0.0 in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: tableschema-to-template>=0.0.13 in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.0.13)
# Requirement already satisfied: xlrd>=2.0.1 in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: ijson>=3.2.3 in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: xlwt>=1.3.0 in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: loguru in ./.venv/lib/python3.10/site-packages (from hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: jsonpath_ng in ./.venv/lib/python3.10/site-packages (from libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: ply in ./.venv/lib/python3.10/site-packages (from libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: python-io-wrapper>=0.2 in ./.venv/lib/python3.10/site-packages (from libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (from libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: structlog in ./.venv/lib/python3.10/site-packages (from libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (24.4.0)
# Requirement already satisfied: unidecode in ./.venv/lib/python3.10/site-packages (from libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (1.3.8)
# Requirement already satisfied: urllib3 in ./.venv/lib/python3.10/site-packages (from libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: wheel in ./.venv/lib/python3.10/site-packages (from libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (0.44.0)
# Requirement already satisfied: xlrd3>=1.1.0 in ./.venv/lib/python3.10/site-packages (from libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (8.6.3)
# Requirement already satisfied: pyzmq>=24 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (26.2.0)
# Requirement already satisfied: ipython>=7.23.1 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (8.29.0)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (5.14.3)
# Requirement already satisfied: packaging in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (24.1)
# Requirement already satisfied: tornado>=6.1 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (6.4.1)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (1.8.7)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (5.7.2)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: appnope in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (0.1.7)
# Requirement already satisfied: psutil in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.10/site-packages (from ipykernel->jupyter->-r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in ./.venv/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 3)) (3.0.13)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in ./.venv/lib/python3.10/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 3)) (4.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.venv/lib/python3.10/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 3)) (3.0.48)
# Requirement already satisfied: pygments in ./.venv/lib/python3.10/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./.venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 3)) (2.27.3)
# Requirement already satisfied: setuptools>=40.1.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 3)) (65.5.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 3)) (2.14.2)
# Requirement already satisfied: async-lru>=1.0.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 3)) (2.2.5)
# Requirement already satisfied: httpx>=0.25.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 3)) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in ./.venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 3)) (3.1.4)
# Requirement already satisfied: notebook-shim>=0.2 in ./.venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 3)) (0.2.4)
# Requirement already satisfied: tomli>=1.2.2 in ./.venv/lib/python3.10/site-packages (from jupyterlab->jupyter->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: defusedxml in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: nbformat>=5.7 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: markupsafe>=2.0 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: bleach!=5.0.0 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (6.2.0)
# Requirement already satisfied: beautifulsoup4 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (4.12.3)
# Requirement already satisfied: tinycss2 in ./.venv/lib/python3.10/site-packages (from nbconvert->jupyter->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.venv/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: isodate>=0.6 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: jsonschema>=4.20 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (4.23.0)
# Requirement already satisfied: chardet>=3.0 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (5.2.0)
# Requirement already satisfied: stringcase>=1.2 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: rfc3986>=1.4 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: typer>=0.12 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.12.5)
# Requirement already satisfied: marko>=1.0 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: petl>=1.6 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (1.7.15)
# Requirement already satisfied: humanize>=4.2 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (4.11.0)
# Requirement already satisfied: simpleeval>=0.9.11 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (1.0.3)
# Requirement already satisfied: validators>=0.18 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.34.0)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (24.2.0)
# Requirement already satisfied: python-slugify>=1.2 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (8.0.4)
# Requirement already satisfied: pydantic>=2.0 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2.9.2)
# Requirement already satisfied: tabulate>=0.8.10 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.9.0)
# Requirement already satisfied: pyyaml>=5.3 in ./.venv/lib/python3.10/site-packages (from frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (1.0.6)
# Requirement already satisfied: certifi in ./.venv/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (2024.8.30)
# Requirement already satisfied: idna in ./.venv/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (3.10)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: anyio in ./.venv/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (4.6.2.post1)
# Requirement already satisfied: h11<0.15,>=0.13 in ./.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (0.14.0)
# Requirement already satisfied: stack-data in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (0.6.3)
# Requirement already satisfied: decorator in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (0.19.1)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (4.9.0)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r requirements.txt (line 3)) (4.3.6)
# Requirement already satisfied: send2trash>=1.8.2 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (1.8.3)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (0.10.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (0.21.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (23.1.0)
# Requirement already satisfied: websocket-client>=1.7 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: overrides>=5.0 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (7.7.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.venv/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (0.5.3)
# Requirement already satisfied: babel>=2.10 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 3)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in ./.venv/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r requirements.txt (line 3)) (0.9.25)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter->-r requirements.txt (line 3)) (2.20.0)
# Requirement already satisfied: et-xmlfile in ./.venv/lib/python3.10/site-packages (from openpyxl>=3.1.2->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r requirements.txt (line 3)) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests->libhxl>=5.2.2->hdx-python-country->-r requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: xlsxwriter>=1.2.8 in ./.venv/lib/python3.10/site-packages (from tableschema-to-template>=0.0.13->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter->-r requirements.txt (line 3)) (2.6)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in ./.venv/lib/python3.10/site-packages (from ruamel-yaml->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.2.12)
# Requirement already satisfied: argon2-cffi-bindings in ./.venv/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in ./.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2024.10.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.21.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (0.1.1)
# Requirement already satisfied: rfc3339-validator in ./.venv/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.10/site-packages (from pydantic>=2.0->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./.venv/lib/python3.10/site-packages (from pydantic>=2.0->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2.23.4)
# Requirement already satisfied: text-unidecode>=1.3 in ./.venv/lib/python3.10/site-packages (from python-slugify>=1.2->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (1.3)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.10/site-packages (from typer>=0.12->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.10/site-packages (from typer>=0.12->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.10/site-packages (from typer>=0.12->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: jsonpointer>1.13 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: isoduration in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (20.11.0)
# Requirement already satisfied: fqdn in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: webcolors>=24.6.0 in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (24.8.0)
# Requirement already satisfied: uri-template in ./.venv/lib/python3.10/site-packages (from jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.12->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: cffi>=1.0.1 in ./.venv/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (1.17.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r requirements.txt (line 3)) (2.22)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: arrow>=0.15.0 in ./.venv/lib/python3.10/site-packages (from isoduration->jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./.venv/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.20->frictionless>=5.18.0->hdx-python-utilities>=3.7.4->hdx-python-country->-r requirements.txt (line 2)) (2.9.0.20241003)
#
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Import libraries
from countryinfo import CountryInfo
from dotenv import load_dotenv
load_dotenv()
from hdx.location.country import Country
import numpy as np
import os
import pandas as pd
from phone_iso3166.country import *
import random
import sys
import uuid

# %%
# Utility function to generate UUID
def generate_uuid(index, seed):
    rd = random.Random()
    rd.seed(seed + index)
    return uuid.UUID(int=rd.getrandbits(128), version=4)

# %%
# Load data path from .env
data_path = os.environ.get("DATA_PATH")

# %%
# Download country svg flags as a zip file then unzip the file
! wget https://github.com/lipis/flag-icons/archive/main.zip -P $DATA_PATH
! unzip "${DATA_PATH}/main.zip" -d "${DATA_PATH}flag_svg_data"
! rm -r  ${DATA_PATH}/main.zip
# Out:
# --2024-11-09 16:33:53--  https://github.com/lipis/flag-icons/archive/main.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/lipis/flag-icons/zip/refs/heads/main [following]
# --2024-11-09 16:33:53--  https://codeload.github.com/lipis/flag-icons/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.121.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.121.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1556150 (1.5M) [application/zip]
# Saving to: ‘../Data/main.zip’
#
# main.zip            100%[===================>]   1.48M  3.53MB/s    in 0.4s
#
# 2024-11-09 16:33:54 (3.53 MB/s) - ‘../Data/main.zip’ saved [1556150/1556150]
#
# Archive:  ../Data//main.zip
# e119b66129af6dd849754ccf25dfbf81d4a306d5
#    creating: ../Data/flag_svg_data/flag-icons-main/
#    creating: ../Data/flag_svg_data/flag-icons-main/.github/
#   inflating: ../Data/flag_svg_data/flag-icons-main/.github/dependabot.yml
#    creating: ../Data/flag_svg_data/flag-icons-main/.github/workflows/
#   inflating: ../Data/flag_svg_data/flag-icons-main/.github/workflows/flags.yml
#   inflating: ../Data/flag_svg_data/flag-icons-main/.github/workflows/format.yml
#   inflating: ../Data/flag_svg_data/flag-icons-main/.github/workflows/npm-publish.yml
#  extracting: ../Data/flag_svg_data/flag-icons-main/.gitignore
#  extracting: ../Data/flag_svg_data/flag-icons-main/.prettierignore
#  extracting: ../Data/flag_svg_data/flag-icons-main/.prettierrc.json
#   inflating: ../Data/flag_svg_data/flag-icons-main/404.html
#   inflating: ../Data/flag_svg_data/flag-icons-main/CHANGELOG.md
#  extracting: ../Data/flag_svg_data/flag-icons-main/CNAME
#   inflating: ../Data/flag_svg_data/flag-icons-main/LICENSE
#   inflating: ../Data/flag_svg_data/flag-icons-main/README.md
#    creating: ../Data/flag_svg_data/flag-icons-main/assets/
#   inflating: ../Data/flag_svg_data/flag-icons-main/assets/docs.css
#   inflating: ../Data/flag_svg_data/flag-icons-main/assets/docs.js
#   inflating: ../Data/flag_svg_data/flag-icons-main/assets/og.png
#   inflating: ../Data/flag_svg_data/flag-icons-main/composer.json
#   inflating: ../Data/flag_svg_data/flag-icons-main/country.json
#    creating: ../Data/flag_svg_data/flag-icons-main/css/
#   inflating: ../Data/flag_svg_data/flag-icons-main/css/flag-icons.css
#   inflating: ../Data/flag_svg_data/flag-icons-main/css/flag-icons.min.css
#   inflating: ../Data/flag_svg_data/flag-icons-main/favicon.ico
#   inflating: ../Data/flag_svg_data/flag-icons-main/flag-ids.py
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags.py
#    creating: ../Data/flag_svg_data/flag-icons-main/flags/
#    creating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ad.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ae.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/af.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ag.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ai.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/al.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/am.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ao.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/aq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ar.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/arab.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/as.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/at.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/au.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/aw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ax.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/az.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ba.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bb.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bd.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/be.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bi.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bo.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/br.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bs.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/by.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/bz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ca.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cd.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cefta.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ch.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ci.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ck.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/co.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cx.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cy.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/cz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/de.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/dg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/dj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/dk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/dm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/do.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/dz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/eac.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ec.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ee.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/eg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/eh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/er.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/es-ct.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/es-ga.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/es-pv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/es.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/et.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/eu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/fi.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/fj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/fk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/fm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/fo.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/fr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ga.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gb-eng.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gb-nir.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gb-sct.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gb-wls.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gb.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gd.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ge.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gi.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gs.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/gy.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/hk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/hm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/hn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/hr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ht.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/hu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ic.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/id.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ie.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/il.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/im.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/in.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/io.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/iq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ir.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/is.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/it.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/je.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/jm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/jo.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/jp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ke.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/kg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/kh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ki.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/km.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/kn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/kp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/kr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/kw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ky.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/kz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/la.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/lb.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/lc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/li.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/lk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/lr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ls.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/lt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/lu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/lv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ly.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ma.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/md.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/me.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ml.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mo.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ms.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mx.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/my.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/mz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/na.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/nc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ne.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/nf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ng.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ni.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/nl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/no.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/np.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/nr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/nu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/nz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/om.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pa.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pe.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ph.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ps.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/pw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/py.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/qa.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/re.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ro.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/rs.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ru.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/rw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sa.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sb.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sd.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/se.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sh-ac.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sh-hl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sh-ta.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/si.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/so.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ss.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/st.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sx.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sy.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/sz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/td.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/th.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/to.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/tz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ua.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ug.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/um.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/un.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/us.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/uy.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/uz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/va.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/vc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ve.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/vg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/vi.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/vn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/vu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/wf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ws.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/xk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/xx.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/ye.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/yt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/za.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/zm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/1x1/zw.svg
#    creating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ad.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ae.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/af.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ag.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ai.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/al.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/am.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ao.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/aq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ar.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/arab.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/as.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/at.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/au.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/aw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ax.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/az.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ba.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bb.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bd.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/be.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bi.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bo.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/br.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bs.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/by.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/bz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ca.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cd.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cefta.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ch.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ci.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ck.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/co.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cx.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cy.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/cz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/de.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/dg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/dj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/dk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/dm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/do.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/dz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/eac.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ec.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ee.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/eg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/eh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/er.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/es-ct.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/es-ga.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/es-pv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/es.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/et.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/eu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/fi.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/fj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/fk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/fm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/fo.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/fr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ga.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gb-eng.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gb-nir.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gb-sct.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gb-wls.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gb.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gd.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ge.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gi.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gs.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/gy.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/hk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/hm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/hn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/hr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ht.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/hu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ic.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/id.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ie.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/il.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/im.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/in.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/io.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/iq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ir.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/is.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/it.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/je.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/jm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/jo.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/jp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ke.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/kg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/kh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ki.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/km.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/kn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/kp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/kr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/kw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ky.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/kz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/la.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/lb.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/lc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/li.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/lk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/lr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ls.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/lt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/lu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/lv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ly.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ma.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/md.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/me.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ml.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mo.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mp.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mq.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ms.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mx.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/my.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/mz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/na.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/nc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ne.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/nf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ng.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ni.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/nl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/no.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/np.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/nr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/nu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/nz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/om.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pa.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pe.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ph.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ps.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/pw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/py.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/qa.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/re.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ro.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/rs.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ru.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/rw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sa.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sb.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sd.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/se.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sh-ac.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sh-hl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sh-ta.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sh.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/si.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/so.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ss.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/st.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sx.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sy.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/sz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/td.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/th.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tj.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tl.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/to.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tr.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tv.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/tz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ua.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ug.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/um.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/un.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/us.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/uy.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/uz.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/va.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/vc.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ve.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/vg.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/vi.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/vn.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/vu.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/wf.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ws.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/xk.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/xx.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/ye.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/yt.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/za.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/zm.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/flags/4x3/zw.svg
#   inflating: ../Data/flag_svg_data/flag-icons-main/index.html
#   inflating: ../Data/flag_svg_data/flag-icons-main/maven.sh
#   inflating: ../Data/flag_svg_data/flag-icons-main/package.json
#  extracting: ../Data/flag_svg_data/flag-icons-main/robots.txt
#    creating: ../Data/flag_svg_data/flag-icons-main/sass/
#   inflating: ../Data/flag_svg_data/flag-icons-main/sass/_flag-icons-base.scss
#   inflating: ../Data/flag_svg_data/flag-icons-main/sass/_flag-icons-list.scss
#   inflating: ../Data/flag_svg_data/flag-icons-main/sass/_variables.scss
#   inflating: ../Data/flag_svg_data/flag-icons-main/sass/flag-icons.scss
#   inflating: ../Data/flag_svg_data/flag-icons-main/svgo.config.js
#   inflating: ../Data/flag_svg_data/flag-icons-main/yarn.lock

# %%
# Get path to country flag svg files
country_flags_path = f"{data_path}flag_svg_data/flag-icons-main/flags/1x1/"

# Get country codes from icon name iso2 paths
country_flags_path = os.listdir(country_flags_path)
# print(f"Number of listed countries from icon data: {len(country_flags_path)}")
country_dict = {}
country_dict["country"] = []
country_dict["iso2"] = []
country_dict["iso3"] = []
country_dict["flag_icon_path"] = []

# Build countries df
for index, icon_path in enumerate(country_flags_path):
    country_iso2 = icon_path.split(".")[0].upper()
    country_by_ios2 = Country.get_country_info_from_iso2(country_iso2)
    if country_by_ios2:
        country_name = country_by_ios2["#country+name+preferred"]
        country_dict["iso2"].append(country_iso2)
        country_dict["iso3"].append(country_by_ios2["#country+code+v_iso3"])
        country_dict["country"].append(country_name)
        country_dict["flag_icon_path"].append(f"assets/icons/country_flags/{icon_path}")

country_df = pd.DataFrame(data=country_dict)
country_df.insert(column="id", loc=0, value=[generate_uuid(i, 3770) for i in range(country_df.shape[0])])
country_df.sort_values(by="country", ascending=True, inplace=True, ignore_index=True)
country_df
# Out:
#                                        id         country iso2 iso3  \
# 0    2298f0af-4e56-4980-9db0-7aed25624f91     Afghanistan   AF  AFG
# 1    7c9b5b9f-d1f9-47a4-b80c-1a36b54e02fe         Albania   AL  ALB
# 2    3624c785-5d1f-4e7c-b650-ab849263d99a         Algeria   DZ  DZA
# 3    34775998-2c61-481f-b45e-512d2c2cbc12  American Samoa   AS  ASM
# 4    40230b1d-1529-4d8d-83d6-f9ae58bf45b5         Andorra   AD  AND
# ..                                    ...             ...  ...  ...
# 244  e2950f77-21c5-4e3d-8e5c-4b9d5922ed16  Western Sahara   EH  ESH
# 245  3f9ab77c-1c2b-48e9-ab6b-e240119f4eb4           Yemen   YE  YEM
# 246  a2db17e2-132f-4410-9efb-45127f3c78eb          Zambia   ZM  ZMB
# 247  25b8efa3-7ab8-41f0-a311-d2228d20c482        Zimbabwe   ZW  ZWE
# 248  98cd274f-c97b-4719-8e37-920e5e0fa6b9   Åland Islands   AX  ALA
#
#                         flag_icon_path
# 0    assets/icons/country_flags/af.svg
# 1    assets/icons/country_flags/al.svg
# 2    assets/icons/country_flags/dz.svg
# 3    assets/icons/country_flags/as.svg
# 4    assets/icons/country_flags/ad.svg
# ..                                 ...
# 244  assets/icons/country_flags/eh.svg
# 245  assets/icons/country_flags/ye.svg
# 246  assets/icons/country_flags/zm.svg
# 247  assets/icons/country_flags/zw.svg
# 248  assets/icons/country_flags/ax.svg
#
# [249 rows x 5 columns]

# %%
# Get github open country codes data to get country calling codes
open_countries_data_url ="https://raw.githubusercontent.com/datasets/country-codes/refs/heads/main/data/country-codes.csv"
open_country_dict = pd.read_csv(open_countries_data_url)
open_country_dict
# Out:
#     FIFA   Dial ISO3166-1-Alpha-3 MARC   is_independent  ISO3166-1-numeric  \
# 0    AFG     93               AFG   af              Yes                  4
# 1    ALD    358               ALA            Part of FI                248
# 2    ALB    355               ALB   aa              Yes                  8
# 3    ALG    213               DZA   ae              Yes                 12
# 4    ASA  1-684               ASM   as  Territory of US                 16
# ..   ...    ...               ...  ...              ...                ...
# 248  SAH    212               ESH   ss    In contention                732
# 249  SAH    212               ESH   ss    In contention                732
# 250  YEM    967               YEM   ye              Yes                887
# 251  ZAM    260               ZMB   za              Yes                894
# 252  ZIM    263               ZWE   rh              Yes                716
#
#        GAUL FIPS WMO ISO3166-1-Alpha-2  ...    official_name_ru Global Name  \
# 0       1.0   AF  AF                AF  ...          Афганистан       World
# 1    1242.0                         AX  ...  Аландских островов       World
# 2       3.0   AL  AB                AL  ...             Албания       World
# 3       4.0   AG  AL                DZ  ...               Алжир       World
# 4       5.0   AQ                    AS  ...  Американское Самоа       World
# ..      ...  ...  ..               ...  ...                 ...         ...
# 248   268.0   WI                    EH  ...     Западная Сахара       World
# 249   268.0   WI                    EH  ...     Западная Сахара       World
# 250   269.0   YM  YE                YE  ...               Йемен       World
# 251   270.0   ZA  ZB                ZM  ...              Замбия       World
# 252   271.0   ZI  ZW                ZW  ...            Зимбабве       World
#
#        Capital Continent  TLD                     Languages Geoname ID  \
# 0        Kabul        AS  .af             fa-AF,ps,uz-AF,tk    1149361
# 1    Mariehamn        EU  .ax                         sv-AX     661882
# 2       Tirana        EU  .al                         sq,el     783754
# 3      Algiers        AF  .dz                         ar-DZ    2589581
# 4    Pago Pago        OC  .as                   en-AS,sm,to    5880801
# ..         ...       ...  ...                           ...        ...
# 248   El-Aaiun        AF  .eh                        ar,mey    2461445
# 249   El-Aaiun        AF  .eh                        ar,mey    2461445
# 250      Sanaa        AS  .ye                         ar-YE      69543
# 251     Lusaka        AF  .zm  en-ZM,bem,loz,lun,lue,ny,toi     895949
# 252     Harare        AF  .zw                en-ZW,sn,nr,nd     878675
#
#     CLDR display name EDGAR                                        wikidata_id
# 0         Afghanistan    B2  https://www.wikidata.org/wiki/https://www.wiki...
# 1     Kepulauan Aland   NaN  https://www.wikidata.org/wiki/https://www.wiki...
# 2             Albania    B3  https://www.wikidata.org/wiki/https://www.wiki...
# 3             Algeria    B4  https://www.wikidata.org/wiki/https://www.wiki...
# 4       Samoa Amerika    B5  https://www.wikidata.org/wiki/https://www.wiki...
# ..                ...   ...                                                ...
# 248      Sahara Barat    U5  https://www.wikidata.org/wiki/https://www.wiki...
# 249      Sahara Barat    U5  https://www.wikidata.org/wiki/https://www.wiki...
# 250             Yaman    T7  https://www.wikidata.org/wiki/https://www.wiki...
# 251            Zambia    Y4  https://www.wikidata.org/wiki/https://www.wiki...
# 252          Zimbabwe    Y5  https://www.wikidata.org/wiki/https://www.wiki...
#
# [253 rows x 56 columns]

# %%
# Inner merge of country_dict and open_country_dict to get calling code for countries
country_df = country_df.merge(open_country_dict[["Dial", "ISO3166-1-Alpha-2"]], how="inner", left_on="iso2", right_on="ISO3166-1-Alpha-2")
country_df.drop(labels=["ISO3166-1-Alpha-2"], axis=1, inplace=True)
country_df.rename(columns={"Dial": "calling_code"}, inplace=True)
country_df.drop_duplicates(inplace=True, ignore_index=True)
country_df
# Out:
#                                        id         country iso2 iso3  \
# 0    2298f0af-4e56-4980-9db0-7aed25624f91     Afghanistan   AF  AFG
# 1    7c9b5b9f-d1f9-47a4-b80c-1a36b54e02fe         Albania   AL  ALB
# 2    3624c785-5d1f-4e7c-b650-ab849263d99a         Algeria   DZ  DZA
# 3    34775998-2c61-481f-b45e-512d2c2cbc12  American Samoa   AS  ASM
# 4    40230b1d-1529-4d8d-83d6-f9ae58bf45b5         Andorra   AD  AND
# ..                                    ...             ...  ...  ...
# 243  e2950f77-21c5-4e3d-8e5c-4b9d5922ed16  Western Sahara   EH  ESH
# 244  3f9ab77c-1c2b-48e9-ab6b-e240119f4eb4           Yemen   YE  YEM
# 245  a2db17e2-132f-4410-9efb-45127f3c78eb          Zambia   ZM  ZMB
# 246  25b8efa3-7ab8-41f0-a311-d2228d20c482        Zimbabwe   ZW  ZWE
# 247  98cd274f-c97b-4719-8e37-920e5e0fa6b9   Åland Islands   AX  ALA
#
#                         flag_icon_path calling_code
# 0    assets/icons/country_flags/af.svg           93
# 1    assets/icons/country_flags/al.svg          355
# 2    assets/icons/country_flags/dz.svg          213
# 3    assets/icons/country_flags/as.svg        1-684
# 4    assets/icons/country_flags/ad.svg          376
# ..                                 ...          ...
# 243  assets/icons/country_flags/eh.svg          212
# 244  assets/icons/country_flags/ye.svg          967
# 245  assets/icons/country_flags/zm.svg          260
# 246  assets/icons/country_flags/zw.svg          263
# 247  assets/icons/country_flags/ax.svg          358
#
# [248 rows x 6 columns]

# %%
# Find list of calling codes where a country has multiple
def get_calling_code_list(calling_codes_string):
    return calling_codes_string.split(",")

country_df["calling_code"] = country_df.loc[:, "calling_code"].apply(lambda x: get_calling_code_list(x))
country_df
# Out:
#                                        id         country iso2 iso3  \
# 0    2298f0af-4e56-4980-9db0-7aed25624f91     Afghanistan   AF  AFG
# 1    7c9b5b9f-d1f9-47a4-b80c-1a36b54e02fe         Albania   AL  ALB
# 2    3624c785-5d1f-4e7c-b650-ab849263d99a         Algeria   DZ  DZA
# 3    34775998-2c61-481f-b45e-512d2c2cbc12  American Samoa   AS  ASM
# 4    40230b1d-1529-4d8d-83d6-f9ae58bf45b5         Andorra   AD  AND
# ..                                    ...             ...  ...  ...
# 243  e2950f77-21c5-4e3d-8e5c-4b9d5922ed16  Western Sahara   EH  ESH
# 244  3f9ab77c-1c2b-48e9-ab6b-e240119f4eb4           Yemen   YE  YEM
# 245  a2db17e2-132f-4410-9efb-45127f3c78eb          Zambia   ZM  ZMB
# 246  25b8efa3-7ab8-41f0-a311-d2228d20c482        Zimbabwe   ZW  ZWE
# 247  98cd274f-c97b-4719-8e37-920e5e0fa6b9   Åland Islands   AX  ALA
#
#                         flag_icon_path calling_code
# 0    assets/icons/country_flags/af.svg         [93]
# 1    assets/icons/country_flags/al.svg        [355]
# 2    assets/icons/country_flags/dz.svg        [213]
# 3    assets/icons/country_flags/as.svg      [1-684]
# 4    assets/icons/country_flags/ad.svg        [376]
# ..                                 ...          ...
# 243  assets/icons/country_flags/eh.svg        [212]
# 244  assets/icons/country_flags/ye.svg        [967]
# 245  assets/icons/country_flags/zm.svg        [260]
# 246  assets/icons/country_flags/zw.svg        [263]
# 247  assets/icons/country_flags/ax.svg        [358]
#
# [248 rows x 6 columns]

# %%
# Create dataframe for calling codes
calling_code_df = country_df[["id", "calling_code"]]
calling_code_df.rename(columns={
    "id": "country"
}, inplace=True)
calling_code_df =calling_code_df.explode("calling_code", ignore_index=True)
calling_code_df.insert(column="id", loc=0, value=[generate_uuid(
    i, 1820) for i in range(calling_code_df.shape[0])])
calling_code_df
# Out:
# /var/folders/xx/l33d299s24b396mf6n2yj2600000gn/T/ipykernel_32351/4114922017.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calling_code_df.rename(columns={
#                                        id  \
# 0    f6a2d2dd-b4c6-475e-b93d-dc8c2654b156
# 1    5e48a155-87d5-4fde-9338-ef1a5a229a6c
# 2    8954392e-5d25-4a65-918f-a90bc914bc7d
# 3    f70c2dc8-01ae-49a4-94a8-bb3847e12ed1
# 4    690bcd97-07c3-4a94-b73f-a10a3a85c032
# ..                                    ...
# 245  177cb58d-40b2-4327-9ea9-d2b6a048878e
# 246  306d4d33-4b61-4e76-9e33-0cbbb64eb2bc
# 247  95d2e9c3-33e5-4005-8127-ff47176f9030
# 248  126a03c0-b726-47cb-aa46-20d8c6e60311
# 249  42defa28-dc0c-4a8c-b10c-ae415cb83f41
#
#                                   country calling_code
# 0    2298f0af-4e56-4980-9db0-7aed25624f91           93
# 1    7c9b5b9f-d1f9-47a4-b80c-1a36b54e02fe          355
# 2    3624c785-5d1f-4e7c-b650-ab849263d99a          213
# 3    34775998-2c61-481f-b45e-512d2c2cbc12        1-684
# 4    40230b1d-1529-4d8d-83d6-f9ae58bf45b5          376
# ..                                    ...          ...
# 245  e2950f77-21c5-4e3d-8e5c-4b9d5922ed16          212
# 246  3f9ab77c-1c2b-48e9-ab6b-e240119f4eb4          967
# 247  a2db17e2-132f-4410-9efb-45127f3c78eb          260
# 248  25b8efa3-7ab8-41f0-a311-d2228d20c482          263
# 249  98cd274f-c97b-4719-8e37-920e5e0fa6b9          358
#
# [250 rows x 3 columns]

# %%
# Ensure that there are no null values for any of the values in country_df (ensure that the inner merge was executed successfully)
country_df.isna().sum()
# Out:
# id                0
# country           0
# iso2              0
# iso3              0
# flag_icon_path    0
# calling_code      0
# dtype: int64

# %%
# Create dataframe for sexes
sex_data = {
    "code": [1, 2],
    "sex": ["Male", "Female"],
    "icon_path": ["assets/icons/mars-solid.svg", "assets/icons/venus-solid.svg"]
}
sex_df = pd.DataFrame(sex_data)
sex_df.insert(column="id", loc=0, value=[generate_uuid(i, 2024) for i in range(sex_df.shape[0])])
sex_df
# Out:
#                                      id  code     sex  \
# 0  940eee3c-ba6f-475c-ae84-496e7857dd86     1    Male
# 1  d66887a3-a556-4782-952b-f8818ec8d8bc     2  Female
#
#                       icon_path
# 0   assets/icons/mars-solid.svg
# 1  assets/icons/venus-solid.svg

# %%
# Create dataframe for diets
diet_data = {
    "diet": ["Cholesterol-friendly", "Diabetic", "Dukan", "Hypertension-friendly", "Ketogenic", "Paleo", "Pescatarian", "Vegan", "Vegetarian"],
    "description": [
        "Low intake of LDL or bad cholesterol by reducing saturated or trans fat, higher intake of unsatuared fats such as those found in fish, nuts and olive oil, higher intake of fibre",
        "Low intake of sugar and simple carbohydrates with a focus on whole grains, lean proteins, fruits and vegetables",
        "High-protein, low-carb diet for weight loss",
        "Low sodium and trans-fat intake with a focus on high potassium intake",
        "Low-carb, high-fat diet that puts the body into ketosis where it burns fat for energy instead of glucose",
        "Hunter-gather like diet of our ancestors - unprocessed foods such as nuts, vegtables, fruits and meat, excludes dairy, legume and grains",
        "Includes fish but excludes other kinds of meat",
        "Excludes not only meat but also animal-derived products such as milk, eggs and honey - strong focus on plant-based foods",
        "Excludes meat but may include other animal-derived products such as milk, eggs and honey - strong focus on plant-based foods"
    ],
}
diet_df = pd.DataFrame(data=diet_data)
diet_df.insert(column="id", loc=0, value=[generate_uuid(
    i, 5416) for i in range(diet_df.shape[0])])
diet_df
# Out:
#                                      id                   diet  \
# 0  1f655136-7ad1-4b4e-b234-8c36f2519625   Cholesterol-friendly
# 1  5cb10763-0638-420e-a2a5-96b0bab23a07               Diabetic
# 2  a25635a4-aca7-443d-81a4-9c4a085609e9                  Dukan
# 3  3cb69109-86c1-452a-b7a7-1ce507d7e20c  Hypertension-friendly
# 4  e850791f-5c9e-40a5-8ba3-7e0aaa989940              Ketogenic
# 5  fe0ca4f7-317d-40c6-b11f-5e0de0435d09                  Paleo
# 6  0b7ad304-2fae-4f1c-b9f1-0ab397f12dbf            Pescatarian
# 7  7c6d03ea-ab8c-4109-b684-cfb401c53859                  Vegan
# 8  dc6bfaaf-c9f6-461c-a0e5-2be76e0049d8             Vegetarian
#
#                                          description
# 0  Low intake of LDL or bad cholesterol by reduci...
# 1  Low intake of sugar and simple carbohydrates w...
# 2        High-protein, low-carb diet for weight loss
# 3  Low sodium and trans-fat intake with a focus o...
# 4  Low-carb, high-fat diet that puts the body int...
# 5  Hunter-gather like diet of our ancestors - unp...
# 6     Includes fish but excludes other kinds of meat
# 7  Excludes not only meat but also animal-derived...
# 8  Excludes meat but may include other animal-der...

# %%
# Create dataframe for skin types
skin_data = {
    "skin_type": ["Combination", "Dry", "Normal", "Oily", "Sensitive"],
    "description": [
        "Oily appearance across the T-zone (forehead, nose and chin) but typically dry across the rest of the skin",
        "Little moisture causing tight, flaky and dull appearance of the skin",
        "Balanced skin, not too oily nor too dry",
        "Excessive sebum production in the skin with shiny appearance, clogged pores and acne",
        "Prone to irritation and redness in response to products"
    ]
}
skin_df = pd.DataFrame(data=skin_data)
skin_df.insert(column="id", loc=0, value=[generate_uuid(i, 1392) for i in range(skin_df.shape[0])])
skin_df
# Out:
#                                      id    skin_type  \
# 0  71c8e9be-df3e-4f4f-a634-650242d730a9  Combination
# 1  fb8aa806-58b5-47eb-810c-233160679941          Dry
# 2  4e7273a2-72f2-48c8-ad0f-1bb5658f5cdb       Normal
# 3  ecec9a70-409f-4841-9a69-3faea939374b         Oily
# 4  34a080c1-be36-4c87-be4d-3a14129bcf1e    Sensitive
#
#                                          description
# 0  Oily appearance across the T-zone (forehead, n...
# 1  Little moisture causing tight, flaky and dull ...
# 2            Balanced skin, not too oily nor too dry
# 3  Excessive sebum production in the skin with sh...
# 4  Prone to irritation and redness in response to...

# %%
# Create dataframe for blood types
blood_type_data = {
    "blood_type": ["A+", "A-", "AB+", "AB-", "B+", "B-", "O+", "O-"],
    "description": [
        "Has A antigens and Rh factor",
        "Has A antigens, no Rh factor",
        "Has A and B antigens and Rh factor (universal recipient)",
        "Has A and B antigens, no Rh factor",
        "Has B antigens and Rh factor",
        "Has B antigens, no Rh factor",
        "No antigens, has Rh factor",
        "No antigens, no Rh factor (universal donor)"
    ]
}
blood_type_df = pd.DataFrame(data=blood_type_data)
blood_type_df.insert(column="id", loc=0, value=[generate_uuid(i, 8902) for i in range(blood_type_df.shape[0])])
blood_type_df
# Out:
#                                      id blood_type  \
# 0  f7331ae5-b8ac-4986-8fb1-b298c4252e63         A+
# 1  99e702ce-fde9-43f2-8c56-68cfe226e6a4         A-
# 2  89e91176-c302-4622-a936-9650005de900        AB+
# 3  4aec66a9-2c8d-447e-81fd-1874afd21ddf        AB-
# 4  d1b3dacd-3e89-4bc7-93d7-018f1ea71e30         B+
# 5  f21668f7-c753-47d7-95ed-a5cd10c592fa         B-
# 6  369f1a24-e30e-4b80-8d0b-a539da00df86         O+
# 7  65a4b8f6-194a-4df3-ae03-8a954ed5ee89         O-
#
#                                          description
# 0                       Has A antigens and Rh factor
# 1                       Has A antigens, no Rh factor
# 2  Has A and B antigens and Rh factor (universal ...
# 3                 Has A and B antigens, no Rh factor
# 4                       Has B antigens and Rh factor
# 5                       Has B antigens, no Rh factor
# 6                         No antigens, has Rh factor
# 7        No antigens, no Rh factor (universal donor)

# %%
# Save dataframes as csv files
if not os.path.exists(f"{data_path}/csv"):
    os.makedirs(f"{data_path}/csv")

country_df.to_csv(f"{data_path}/csv/country.csv", index=None)
calling_code_df.to_csv(f"{data_path}/csv/calling_code.csv", index=None)
sex_df.to_csv(f"{data_path}/csv/sex.csv", index=None)
diet_df.to_csv(f"{data_path}/csv/diet.csv", index=None)
skin_df.to_csv(f"{data_path}/csv/skin.csv", index=None)
blood_type_df.to_csv(f"{data_path}/csv/blood_type.csv", index=None)
